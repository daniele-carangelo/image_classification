# %% [markdown]
# Convolutional Neural Network on CIFAR-10

# %%
import tensorflow as tf
import tensorflow_datasets as tfds
import matplotlib.pyplot as plt 
import numpy as np
import pandas as pd

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Softmax, Flatten, Dropout, Conv2D, MaxPool2D
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import seaborn as sns

# %% [markdown]
# Load dataset from Tensorflow

# %%
cifar = tf.keras.datasets.cifar10

(train_images, train_labels), (test_images, test_labels) = cifar.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 4s 0us/step

# %%
class_names = ['airplane', 'auto', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %% [markdown]
# Check Shape of Data

# %%
train_images.shape
# Out:
# (50000, 32, 32, 3)

# %% [markdown]
# View image of dataset

# %%
plt.figure()
plt.imshow(train_images[1], cmap= 'gray')
plt.colorbar()
plt.grid(False)
plt.show()

# %% [markdown]
# Resize dataset

# %%
train_images = train_images / 255.0

test_images = test_images / 255.0

# %% [markdown]
# View 25 images with label

# %%
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i], cmap=plt.cm.binary)
    plt.xlabel(class_names[train_labels.item(i)])

plt.show()

# %% [markdown]
# Create Model

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(32, 3, activation='relu', input_shape=(32,32,3)),
    tf.keras.layers.MaxPool2D(2),
    tf.keras.layers.Dropout(0.25),
    tf.keras.layers.Conv2D(64, 3, activation='relu'),
    tf.keras.layers.MaxPool2D(2),
    tf.keras.layers.Dropout(0.25),
    tf.keras.layers.Conv2D(128, 3, activation='relu'),
    tf.keras.layers.Dropout(0.4),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.Dense(10, activation='softmax')
])

# %% [markdown]
# Compile Model

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# Summary model

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 30, 30, 32)        896
#
#  max_pooling2d (MaxPooling2D  (None, 15, 15, 32)       0
#  )
#
#  dropout (Dropout)           (None, 15, 15, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 13, 13, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 6, 6, 64)         0
#  2D)
#
#  dropout_1 (Dropout)         (None, 6, 6, 64)          0
#
#  conv2d_2 (Conv2D)           (None, 4, 4, 128)         73856
#
#  dropout_2 (Dropout)         (None, 4, 4, 128)         0
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 128)               262272
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 356,810
# Trainable params: 356,810
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Train the model

# %%
model.fit(train_images, train_labels, epochs=50)
# Out:
# Epoch 1/50
# /usr/local/lib/python3.9/dist-packages/keras/backend.py:5612: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 1563/1563 [==============================] - 19s 5ms/step - loss: 1.6074 - accuracy: 0.4106
# Epoch 2/50
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.2896 - accuracy: 0.5389
# Epoch 3/50
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.1750 - accuracy: 0.5820
# Epoch 4/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.0972 - accuracy: 0.6112
# Epoch 5/50
# 1563/1563 [==============================] - 7s 4ms/step - loss: 1.0450 - accuracy: 0.6321
# Epoch 6/50
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.0068 - accuracy: 0.6458
# Epoch 7/50
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.9813 - accuracy: 0.6550
# Epoch 8/50
# 1563/1563 [==============================] - 10s 7ms/step - loss: 0.9567 - accuracy: 0.6648
# Epoch 9/50
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.9350 - accuracy: 0.6728
# Epoch 10/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.9163 - accuracy: 0.6784
# Epoch 11/50
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.8988 - accuracy: 0.6854
# Epoch 12/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.8816 - accuracy: 0.6915
# Epoch 13/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.8669 - accuracy: 0.6958
# Epoch 14/50
# 1563/1563 [==============================] - 7s 4ms/step - loss: 0.8560 - accuracy: 0.6996
# Epoch 15/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.8462 - accuracy: 0.7066
# Epoch 16/50
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.8360 - accuracy: 0.7076
# Epoch 17/50
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.8212 - accuracy: 0.7134
# Epoch 18/50
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.8138 - accuracy: 0.7136
# Epoch 19/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.8083 - accuracy: 0.7172
# Epoch 20/50
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.7984 - accuracy: 0.7230
# Epoch 21/50
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.7906 - accuracy: 0.7241
# Epoch 22/50
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.7818 - accuracy: 0.7268
# Epoch 23/50
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.7803 - accuracy: 0.7272
# Epoch 24/50
# 1563/1563 [==============================] - 7s 4ms/step - loss: 0.7727 - accuracy: 0.7298
# Epoch 25/50
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.7654 - accuracy: 0.7332
# Epoch 26/50
# 1563/1563 [==============================] - 7s 4ms/step - loss: 0.7610 - accuracy: 0.7326
# Epoch 27/50
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.7481 - accuracy: 0.7374
# Epoch 28/50
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.7568 - accuracy: 0.7369
# Epoch 29/50
# 1563/1563 [==============================] - 7s 4ms/step - loss: 0.7444 - accuracy: 0.7408
# Epoch 30/50
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.7351 - accuracy: 0.7403
# Epoch 31/50
# 1563/1563 [==============================] - 7s 4ms/step - loss: 0.7377 - accuracy: 0.7429
# Epoch 32/50
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.7321 - accuracy: 0.7431
# Epoch 33/50
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.7263 - accuracy: 0.7479
# Epoch 34/50
# 1563/1563 [==============================] - 7s 4ms/step - loss: 0.7314 - accuracy: 0.7441
# Epoch 35/50
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.7167 - accuracy: 0.7467
# Epoch 36/50
# 1563/1563 [==============================] - 7s 4ms/step - loss: 0.7191 - accuracy: 0.7480
# Epoch 37/50
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.7140 - accuracy: 0.7493
# Epoch 38/50
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.7140 - accuracy: 0.7503
# Epoch 39/50
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.7089 - accuracy: 0.7524
# Epoch 40/50
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.7023 - accuracy: 0.7543
# Epoch 41/50
# 1563/1563 [==============================] - 7s 4ms/step - loss: 0.7028 - accuracy: 0.7551
# Epoch 42/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.7006 - accuracy: 0.7521
# Epoch 43/50
# 1563/1563 [==============================] - 7s 4ms/step - loss: 0.6951 - accuracy: 0.7564
# Epoch 44/50
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.6963 - accuracy: 0.7551
# Epoch 45/50
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.6934 - accuracy: 0.7580
# Epoch 46/50
# 1563/1563 [==============================] - 7s 4ms/step - loss: 0.6901 - accuracy: 0.7583
# Epoch 47/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.6862 - accuracy: 0.7601
# Epoch 48/50
# 1563/1563 [==============================] - 7s 4ms/step - loss: 0.6868 - accuracy: 0.7605
# Epoch 49/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.6788 - accuracy: 0.7608
# Epoch 50/50
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.6855 - accuracy: 0.7601

# %% [markdown]
# Verify Accuracy

# %%
test_loss, test_acc = model.evaluate(test_images,  test_labels, verbose=2)

print('\nTest accuracy:', test_acc)
# Out:
# 313/313 - 1s - loss: 0.6907 - accuracy: 0.7701 - 820ms/epoch - 3ms/step
#
# Test accuracy: 0.7700999975204468

# %% [markdown]
# Predict model

# %%
y_pred = model.predict(test_images)
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %% [markdown]
# Classification Report

# %%
y_pred = [np.argmax(arr) for arr in y_pred]
print(classification_report(test_labels, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.82      0.79      1000
#            1       0.93      0.84      0.89      1000
#            2       0.69      0.64      0.66      1000
#            3       0.62      0.55      0.58      1000
#            4       0.69      0.79      0.74      1000
#            5       0.72      0.64      0.67      1000
#            6       0.73      0.89      0.80      1000
#            7       0.88      0.77      0.82      1000
#            8       0.83      0.90      0.86      1000
#            9       0.85      0.87      0.86      1000
#
#     accuracy                           0.77     10000
#    macro avg       0.77      0.77      0.77     10000
# weighted avg       0.77      0.77      0.77     10000

# %% [markdown]
# Confusion Matrix

# %%
cm = confusion_matrix(test_labels,y_pred)
cm
# Out:
# array([[823,   5,  32,   9,  18,   3,   8,  10,  70,  22],
#        [ 22, 842,   3,   6,   4,   3,  15,   3,  27,  75],
#        [ 75,   1, 636,  47,  86,  47,  72,  17,  11,   8],
#        [ 26,   3,  61, 546,  82, 119, 117,  15,  19,  12],
#        [ 19,   1,  58,  27, 788,  15,  53,  27,  12,   0],
#        [ 16,   1,  48, 158,  52, 636,  42,  26,  12,   9],
#        [  8,   0,  32,  29,  24,   8, 893,   3,   3,   0],
#        [ 16,   1,  30,  34,  77,  51,   9, 767,   5,  10],
#        [ 47,  12,   8,   8,   5,   1,   7,   1, 896,  15],
#        [ 19,  36,   8,  11,   6,   3,  10,   5,  28, 874]])

# %%
disp=ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=class_names)
fig, ax = plt.subplots(figsize=(10,10))
disp.plot(ax=ax);
