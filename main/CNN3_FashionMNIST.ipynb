# %% [markdown]
# Convolutional Neural Network on Fashion-MNIST

# %%
import tensorflow as tf
import tensorflow_datasets as tfds
import matplotlib.pyplot as plt 
import numpy as np
import pandas as pd

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Softmax, Flatten, Dropout, Conv2D, MaxPool2D
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import seaborn as sns

# %% [markdown]
# Load dataset from Tensorflow

# %%
fashion_mnist = tf.keras.datasets.fashion_mnist

(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 0s 0us/step

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %% [markdown]
# Check Shape of Data

# %%
train_images.shape
# Out:
# (60000, 28, 28)

# %% [markdown]
# View image of dataset

# %%
plt.figure()
plt.imshow(train_images[1], cmap= 'gray')
plt.colorbar()
plt.grid(False)
plt.show()

# %% [markdown]
# Resize dataset

# %%
train_images = train_images / 255.0

test_images = test_images / 255.0

# %% [markdown]
# View 25 images with label

# %%
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i], cmap=plt.cm.binary)
    plt.xlabel(class_names[train_labels[i]])
plt.show()

# %% [markdown]
# Create Model

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(32, 3, activation='relu', input_shape=(28,28,1)),
    tf.keras.layers.MaxPool2D(2),
    tf.keras.layers.Dropout(0.25),
    tf.keras.layers.Conv2D(64, 3, activation='relu'),
    tf.keras.layers.MaxPool2D(2),
    tf.keras.layers.Dropout(0.25),
    tf.keras.layers.Conv2D(128, 3, activation='relu'),
    tf.keras.layers.Dropout(0.4),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.Dense(10, activation='softmax')
])

# %% [markdown]
# Compile Model

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# Summary model

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 32)        320
#
#  max_pooling2d (MaxPooling2D  (None, 13, 13, 32)       0
#  )
#
#  dropout (Dropout)           (None, 13, 13, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 11, 11, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 5, 5, 64)         0
#  2D)
#
#  dropout_1 (Dropout)         (None, 5, 5, 64)          0
#
#  conv2d_2 (Conv2D)           (None, 3, 3, 128)         73856
#
#  dropout_2 (Dropout)         (None, 3, 3, 128)         0
#
#  flatten (Flatten)           (None, 1152)              0
#
#  dense (Dense)               (None, 128)               147584
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 241,546
# Trainable params: 241,546
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Train the model

# %%
model.fit(train_images, train_labels, epochs=50)
# Out:
# Epoch 1/50
# /usr/local/lib/python3.9/dist-packages/keras/backend.py:5612: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 1875/1875 [==============================] - 24s 5ms/step - loss: 0.6045 - accuracy: 0.7753
# Epoch 2/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.3973 - accuracy: 0.8549
# Epoch 3/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.3508 - accuracy: 0.8712
# Epoch 4/50
# 1875/1875 [==============================] - 8s 5ms/step - loss: 0.3239 - accuracy: 0.8814
# Epoch 5/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.3099 - accuracy: 0.8852
# Epoch 6/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.3027 - accuracy: 0.8887
# Epoch 7/50
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2933 - accuracy: 0.8918
# Epoch 8/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2834 - accuracy: 0.8939
# Epoch 9/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2819 - accuracy: 0.8959
# Epoch 10/50
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2750 - accuracy: 0.8981
# Epoch 11/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2718 - accuracy: 0.8985
# Epoch 12/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2671 - accuracy: 0.8999
# Epoch 13/50
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.2660 - accuracy: 0.9018
# Epoch 14/50
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2645 - accuracy: 0.9017
# Epoch 15/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2605 - accuracy: 0.9037
# Epoch 16/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2554 - accuracy: 0.9046
# Epoch 17/50
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2513 - accuracy: 0.9064
# Epoch 18/50
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2521 - accuracy: 0.9057
# Epoch 19/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2498 - accuracy: 0.9082
# Epoch 20/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2500 - accuracy: 0.9082
# Epoch 21/50
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2467 - accuracy: 0.9069
# Epoch 22/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2431 - accuracy: 0.9098
# Epoch 23/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2493 - accuracy: 0.9079
# Epoch 24/50
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2432 - accuracy: 0.9086
# Epoch 25/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2450 - accuracy: 0.9086
# Epoch 26/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2398 - accuracy: 0.9107
# Epoch 27/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2418 - accuracy: 0.9098
# Epoch 28/50
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2392 - accuracy: 0.9109
# Epoch 29/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2402 - accuracy: 0.9108
# Epoch 30/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2375 - accuracy: 0.9111
# Epoch 31/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2376 - accuracy: 0.9125
# Epoch 32/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2337 - accuracy: 0.9138
# Epoch 33/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2368 - accuracy: 0.9117
# Epoch 34/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2371 - accuracy: 0.9113
# Epoch 35/50
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2342 - accuracy: 0.9125
# Epoch 36/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2340 - accuracy: 0.9137
# Epoch 37/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2307 - accuracy: 0.9137
# Epoch 38/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2318 - accuracy: 0.9130
# Epoch 39/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2316 - accuracy: 0.9147
# Epoch 40/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2299 - accuracy: 0.9143
# Epoch 41/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2259 - accuracy: 0.9152
# Epoch 42/50
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2271 - accuracy: 0.9151
# Epoch 43/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2279 - accuracy: 0.9151
# Epoch 44/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2300 - accuracy: 0.9147
# Epoch 45/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2278 - accuracy: 0.9142
# Epoch 46/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2301 - accuracy: 0.9143
# Epoch 47/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2253 - accuracy: 0.9160
# Epoch 48/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2263 - accuracy: 0.9161
# Epoch 49/50
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2274 - accuracy: 0.9148
# Epoch 50/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2286 - accuracy: 0.9146

# %% [markdown]
# Verify Accuracy

# %%
test_loss, test_acc = model.evaluate(test_images,  test_labels, verbose=2)

print('\nTest accuracy:', test_acc)
# Out:
# 313/313 - 1s - loss: 0.2363 - accuracy: 0.9166 - 950ms/epoch - 3ms/step
#
# Test accuracy: 0.9165999889373779

# %% [markdown]
# Predict model

# %%
y_pred = model.predict(test_images)
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %% [markdown]
# Classification Report

# %%
y_pred = [np.argmax(arr) for arr in y_pred]
print(classification_report(test_labels, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.89      0.87      1000
#            1       0.99      0.98      0.99      1000
#            2       0.91      0.84      0.87      1000
#            3       0.93      0.91      0.92      1000
#            4       0.83      0.91      0.87      1000
#            5       0.99      0.97      0.98      1000
#            6       0.76      0.76      0.76      1000
#            7       0.94      0.98      0.96      1000
#            8       0.99      0.98      0.98      1000
#            9       0.97      0.95      0.96      1000
#
#     accuracy                           0.92     10000
#    macro avg       0.92      0.92      0.92     10000
# weighted avg       0.92      0.92      0.92     10000

# %% [markdown]
# Confusion Matrix

# %%
cm = confusion_matrix(test_labels,y_pred)
cm
# Out:
# array([[885,   0,  16,  10,   2,   1,  83,   0,   3,   0],
#        [  2, 982,   1,   8,   3,   0,   1,   0,   3,   0],
#        [ 17,   0, 841,   9,  68,   0,  65,   0,   0,   0],
#        [ 16,   4,   7, 906,  36,   0,  30,   0,   0,   1],
#        [  0,   1,  15,  21, 905,   0,  57,   0,   1,   0],
#        [  0,   0,   0,   0,   0, 975,   0,  16,   0,   9],
#        [105,   0,  43,  17,  73,   0, 756,   0,   6,   0],
#        [  0,   0,   0,   0,   0,   3,   0, 982,   0,  15],
#        [  3,   0,   2,   3,   2,   2,   3,   4, 981,   0],
#        [  1,   0,   0,   0,   0,   3,   0,  43,   0, 953]])

# %%
disp=ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=class_names)
fig, ax = plt.subplots(figsize=(10,10))
disp.plot(ax=ax);
