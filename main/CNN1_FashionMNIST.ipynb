# %% [markdown]
# Convolutional Neural Network on Fashion-MNIST

# %%
import tensorflow as tf
import tensorflow_datasets as tfds
import matplotlib.pyplot as plt 
import numpy as np
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Softmax, Flatten, Dropout, Conv2D, MaxPool2D
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import seaborn as sns

# %% [markdown]
# Load dataset from Tensorflow

# %%
fashion_mnist = tf.keras.datasets.fashion_mnist

(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 0s 0us/step

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %% [markdown]
# Check Shape of Data

# %%
train_images.shape
# Out:
# (60000, 28, 28)

# %% [markdown]
# View image of dataset

# %%
plt.figure()
plt.imshow(train_images[1], cmap= 'gray')
plt.colorbar()
plt.grid(False)
plt.show()

# %% [markdown]
# Resize dataset

# %%
train_images = train_images / 255.0

test_images = test_images / 255.0

# %% [markdown]
# View 25 images with label

# %%
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i], cmap=plt.cm.binary)
    plt.xlabel(class_names[train_labels[i]])
plt.show()

# %% [markdown]
# Create Model

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(64, 2, input_shape=(28,28,1), padding='same'),
    tf.keras.layers.MaxPool2D(),
    tf.keras.layers.Dropout(0.20),
    tf.keras.layers.Conv2D(64, 2, padding='same'),
    tf.keras.layers.MaxPool2D(),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(10, activation='softmax')
])

# %% [markdown]
# Compile Model

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# Summary model

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 28, 28, 64)        320
#
#  max_pooling2d (MaxPooling2D  (None, 14, 14, 64)       0
#  )
#
#  dropout (Dropout)           (None, 14, 14, 64)        0
#
#  conv2d_1 (Conv2D)           (None, 14, 14, 64)        16448
#
#  max_pooling2d_1 (MaxPooling  (None, 7, 7, 64)         0
#  2D)
#
#  flatten (Flatten)           (None, 3136)              0
#
#  dense (Dense)               (None, 10)                31370
#
# =================================================================
# Total params: 48,138
# Trainable params: 48,138
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Train the model

# %%
model.fit(train_images, train_labels, epochs=30)
# Out:
# Epoch 1/30
# /usr/local/lib/python3.9/dist-packages/keras/backend.py:5612: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 1875/1875 [==============================] - 18s 3ms/step - loss: 0.4559 - accuracy: 0.8395
# Epoch 2/30
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3349 - accuracy: 0.8823
# Epoch 3/30
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2992 - accuracy: 0.8935
# Epoch 4/30
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2792 - accuracy: 0.9010
# Epoch 5/30
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2641 - accuracy: 0.9068
# Epoch 6/30
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2509 - accuracy: 0.9103
# Epoch 7/30
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2421 - accuracy: 0.9130
# Epoch 8/30
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2328 - accuracy: 0.9154
# Epoch 9/30
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2251 - accuracy: 0.9198
# Epoch 10/30
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2179 - accuracy: 0.9210
# Epoch 11/30
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2124 - accuracy: 0.9233
# Epoch 12/30
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2076 - accuracy: 0.9254
# Epoch 13/30
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2039 - accuracy: 0.9261
# Epoch 14/30
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1979 - accuracy: 0.9289
# Epoch 15/30
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1956 - accuracy: 0.9293
# Epoch 16/30
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1925 - accuracy: 0.9302
# Epoch 17/30
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1897 - accuracy: 0.9304
# Epoch 18/30
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1868 - accuracy: 0.9332
# Epoch 19/30
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1827 - accuracy: 0.9329
# Epoch 20/30
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1818 - accuracy: 0.9343
# Epoch 21/30
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1809 - accuracy: 0.9341
# Epoch 22/30
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1751 - accuracy: 0.9370
# Epoch 23/30
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1753 - accuracy: 0.9366
# Epoch 24/30
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1735 - accuracy: 0.9366
# Epoch 25/30
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1711 - accuracy: 0.9382
# Epoch 26/30
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1714 - accuracy: 0.9375
# Epoch 27/30
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1702 - accuracy: 0.9376
# Epoch 28/30
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1660 - accuracy: 0.9394
# Epoch 29/30
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.1668 - accuracy: 0.9385
# Epoch 30/30
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1643 - accuracy: 0.9385

# %% [markdown]
# Verify Accuracy

# %%
test_loss, test_acc = model.evaluate(test_images,  test_labels, verbose=2)

print('\nTest accuracy:', test_acc)
# Out:
# 313/313 - 1s - loss: 0.3426 - accuracy: 0.8948 - 991ms/epoch - 3ms/step
#
# Test accuracy: 0.8948000073432922

# %% [markdown]
# Model Predict

# %%
y_pred = model.predict(test_images)
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %% [markdown]
# Classification Report

# %%
y_pred = [np.argmax(arr) for arr in y_pred]
print(classification_report(test_labels, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.80      0.83      1000
#            1       0.98      0.99      0.98      1000
#            2       0.90      0.76      0.83      1000
#            3       0.91      0.88      0.90      1000
#            4       0.77      0.91      0.83      1000
#            5       0.98      0.96      0.97      1000
#            6       0.70      0.75      0.73      1000
#            7       0.95      0.96      0.95      1000
#            8       0.98      0.97      0.97      1000
#            9       0.95      0.96      0.96      1000
#
#     accuracy                           0.89     10000
#    macro avg       0.90      0.89      0.90     10000
# weighted avg       0.90      0.89      0.90     10000

# %% [markdown]
# Confusion Matrix

# %%
cm = confusion_matrix(test_labels,y_pred)
cm
# Out:
# array([[803,   2,  15,  20,   4,   1, 146,   0,   8,   1],
#        [  2, 987,   0,   6,   5,   0,   0,   0,   0,   0],
#        [ 20,   2, 760,   7, 133,   0,  77,   0,   1,   0],
#        [ 17,  14,  11, 882,  31,   1,  42,   0,   2,   0],
#        [  2,   0,  21,  21, 913,   0,  42,   0,   1,   0],
#        [  0,   0,   0,   0,   0, 962,   0,  19,   1,  18],
#        [ 84,   2,  30,  27,  95,   0, 752,   0,  10,   0],
#        [  0,   0,   0,   0,   0,   8,   0, 960,   0,  32],
#        [  5,   2,   3,   2,   7,   3,   8,   2, 967,   1],
#        [  1,   0,   0,   0,   0,   6,   0,  31,   0, 962]])

# %%
disp=ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=class_names)
fig, ax = plt.subplots(figsize=(10,10))
disp.plot(ax=ax);
